# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
def perceptron(X,y,Learn):

    w=np.array([0,0])
    b = 0
    counter = 0
    R = max([np.linalg.norm(val) for val in X])

    while True:
        for num,val in enumerate(X):
            if y[num] * (np.dot(val,w)+b) <= 0:
                w = w + (Learn * y[num] * val)
                b = b + (Learn * y[num] * (R**2))
            else:
                return (w,b,counter)
            counter += 1

# %%
from sklearn import datasets
X, y= datasets.make_blobs(centers=2,center_box=(1.0,10.0),n_samples=10)
y = [val-1 if val == 0 else val for val in y]
X1 = [X[i][0] for i in range(len(X))]
X2 = [X[i][1] for i in range(len(X))]
plt.scatter(X1,X2,c=y,)

# %%
w, b, counter = perceptron(X,y,0.01)
print(w)
print(b)
print(counter)
# Out:
# [0.07261026 0.03962271]
# 1.3224651386871313
# 1
