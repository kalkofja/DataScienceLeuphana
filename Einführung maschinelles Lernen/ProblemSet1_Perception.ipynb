# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
from sklearn import datasets
X, y= datasets.make_blobs(centers=2,center_box=(0.0,20.0),n_samples=25)
X1 = [X[i][0] for i in range(len(X))]
X2 = [X[i][1] for i in range(len(X))]
# Out:
# array([0, 1, 0, 1])

# %%
plt.scatter(X1,X2)

# %%
def perceptron ():
