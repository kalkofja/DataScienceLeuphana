# %%
import numpy as np 
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
def perceptron(X,y,Learn):

    w=np.array([0,0])
    b = 0
    R = max([np.linalg.norm(val) for val in X])
    counter = 0
    made_mistake = True

    while made_mistake:
        made_mistake = False
        for num,val in enumerate(X):
            if y[num] * (np.dot(val,w)+b) <= 0:
                w = w + (Learn * y[num] * val)
                b = b + (Learn * y[num] * (R**2))
                counter += 1
                made_mistake = True

  
    return (w,b,counter)

# %%
from sklearn import datasets
X, y= datasets.make_blobs(centers=2,n_samples=10,n_features=2)
y = [val-1 if val == 0 else val for val in y]
X1 = X[:,0]
X2 = X[:,1]
plt.scatter(X1,X2,c=y)

# %%
w, b, counter = perceptron(X,y,0.5)
print(w)
print(b)
print(counter)
# Out:
# [-8.47620068 -1.98858006]
# 0.0
# 2
